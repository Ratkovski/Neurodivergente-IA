# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratkovski/Neurodivergente-IA/blob/main/neurodivergente_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neurodivergente Ai 📚 🌻
# È focado para a elaboração de conteùdo de estudo para pessoas neurodivergentes o qual o sistema da sugestões de conteúdo conforme a neurodivergência, idade e qual o assunto escolhido e qual o grau de dificuldade do estudo.
#
# # Observação
# O conteúdo deve ser revisado por especialistas pois não atuo na aréa mas gostaria que fosse possivel ter uma qualidade de estudos igual para todos.

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
from google.colab import userdata
api_key = userdata.get('SECRET_KEY')
genai.configure(api_key=api_key)

# %%
#Listando os modelos disponíveis
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
generation_config={
    "temperature": 0.5,
    "candidate_count":1,
}

# %%
safety_settings={
    'HATE':'BLOCK_NONE',
    'HARASSMENT':'BLOCK_NONE',
    'SEXUAL':'BLOCK_NONE',
    'DANGEROUS':'BLOCK_NONE',

    }

# %%
system_instruction ="Você é um especialista em neurodivergência, com especializações em neuro-aprendizagem, phd em psicologia educacional e comportamental o qual vai criar as atividades que forem solicitadas de acordo com as informações coletadas "
model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                               generation_config=generation_config,
                              system_instruction=system_instruction,
                               safety_settings=safety_settings)

# %%
# pegando dados do aluno
# Para o futuro : pegar mais caracteristicas que sejam importantes para ajudar na organização do plano de estudo
def get_informacao_usuario():
  neurodivergencia = input("Qual o tipo de neurodivergência (Exemplo: autismo, TDAH, dislexia)? ")
  idade = int(input("Qual a idade do aluno? "))
  assunto = input("Qual o assunto a ser ensinado? ")
  nivel = input("Nivel de dificuldade de estudo ")
  return neurodivergencia,idade,assunto,nivel

# %%
def processar_resposta(resposta):
    print(resposta.text)

# %%
def main():
    chat = model.start_chat(history=[])
    #verifica se a pessoa que continuar a pesquisa
    prosseguir = input("Gostaria de prosseguir? Digite 'yes': ")
    if prosseguir.lower() == "yes":
        while True:
            neurodivergencia, idade, assunto, nivel = get_informacao_usuario()
        #monta o prompt para podermos ter a resposta do model
            prompt = (
                f"Gostaria de um planejamento de estudo para uma pessoa que tem a "
                f"neurodivergência {neurodivergencia} e sua idade é {idade} a qual "
                f"gostaria de aprender sobre {assunto} e o nível de dificuldade seja {nivel}. "
                f"Inclua links do YouTube: "
            )
        #envia o prompt e monta a resposta
            response = chat.send_message(prompt)
            processar_resposta(response)

            #verifica se a pessoa que continuar a pesquisa ou quer sair do sistema
            continuar = input("Gostaria de continuar? Digite 'yes' para continuar ou qualquer outra coisa para sair: ")
            if continuar.lower() != "yes":
                break
    else:
        print("Saindo do sistema.")

if __name__ == "__main__":
    main()
# Out:
# Gostaria de prosseguir? Digite 'yes': yes
# Qual o tipo de neurodivergência (Exemplo: autismo, TDAH, dislexia)? autismo
# Qual a idade do aluno? 18
# Qual o assunto a ser ensinado? geografia
# Nivel de dificuldade de estudo avançado
# ## Plano de Estudo de Geografia (Nível Avançado) para Autistas (18 anos)
#
# Este plano foi elaborado considerando as necessidades específicas de aprendizagem de pessoas autistas, focando em uma abordagem estruturada, multissensorial e com suporte visual.
#
# **Objetivo:** Compreensão profunda da geografia em suas diversas áreas, com foco em análise crítica e desenvolvimento de habilidades de pesquisa.
#
# **Duração:** Flexível, adaptável ao ritmo individual.
#
# **Materiais:**
#
# * Livros didáticos de geografia avançada (ex: Geografia Geral e do Brasil - Vesentini)
# * Atlas geográfico detalhado
# * Caderno de anotações
# * Canetas coloridas/marca-texto
# * Software de mapas mentais (ex: XMind, MindManager)
# * Fichas de estudo
# ...
